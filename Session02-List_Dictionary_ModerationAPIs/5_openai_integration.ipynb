# %%
import os
from dotenv import load_dotenv

load_dotenv(override=True, dotenv_path="../.env.local")
my_api_key = os.getenv("OPENAI_API_KEY")

# print (my_api_key)

# %%
# %pip install openai

# %%
from openai import OpenAI
my_client = OpenAI(api_key=my_api_key)
my_client

# %%
def ask_question(prompt):
    print(f"User asked: {prompt}")
    # my_client.chat.completions.create
    system_prompt_message={"role": "system", "content": "You are a helpful assistant. Answer as concisely as possible."}
    user_prompt_message={"role": "user", "content": prompt}
    llm_response = my_client.chat.completions.create(
        model="gpt-5-nano",
        messages=[system_prompt_message, user_prompt_message]   
    )
    print (llm_response)

    # prompt = ChatPromptTemplate.from_messages([
    #     ("system", "You are a helpful assistant."),
    #     ("human", "{question}")
    # ])
    # # print(prompt.invoke({"question": "What is AI?"}))
    # prompt | llm
    # llm = OpenAI(model="gpt-5-nano")

    return llm_response.choices[0].message.content  

    # parser = StrOutputParser()
    # result = parser.invoke(resp)
    # return result

# %%
import time
while True:
    # Ask user for a question
    user_prompt = input("Ask something: ")

    if (user_prompt.lower() != 'quit'):
        # Get and print the response
        response = ask_question(user_prompt)
        print("\nOpenAI says:", response)
        
        # add delay of 3 seconds
        time.sleep(3)
    else:
        print("Exiting...")
        break
# Out:
# User asked: when is summer solstice?
# ChatCompletion(id='chatcmpl-CxnM6gzr8gCWpVPXfwd1cc245L2Cu', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='- Northern Hemisphere: around June 20–22, typically June 21. This is the point when the sun is at its northernmost declination (+23.44°) and the day is longest.\n- Southern Hemisphere: around December 20–23, typically December 21. Here the sun is at its southernmost declination (-23.44°).\n\nExact date/time varies each year and by location. If you share your year and city/latitude, I can give the precise moment for you.', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1768367110, model='gpt-5-nano-2025-08-07', object='chat.completion', service_tier='default', system_fingerprint=None, usage=CompletionUsage(completion_tokens=753, prompt_tokens=30, total_tokens=783, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=640, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
#
# OpenAI says: - Northern Hemisphere: around June 20–22, typically June 21. This is the point when the sun is at its northernmost declination (+23.44°) and the day is longest.
# - Southern Hemisphere: around December 20–23, typically December 21. Here the sun is at its southernmost declination (-23.44°).
#
# Exact date/time varies each year and by location. If you share your year and city/latitude, I can give the precise moment for you.
# Exiting...
