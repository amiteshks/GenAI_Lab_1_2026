# %%
import os
from dotenv import load_dotenv

load_dotenv(override=True, dotenv_path="../.env.local")
my_api_key = os.getenv("OPENAI_API_KEY")

# print (my_api_key)

# %%
# %pip install openai

# %%
from openai import OpenAI
my_client = OpenAI(api_key=my_api_key)
my_client
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[3], line 2
#       1 from openai import OpenAI
# ----> 2 my_client = OpenAI(api_key=my_api_key)
#       3 my_client
#
# File ~/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages/openai/_client.py:137, in OpenAI.__init__(self, api_key, organization, project, webhook_secret, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     135     api_key = os.environ.get("OPENAI_API_KEY")
#     136 if api_key is None:
# --> 137     raise OpenAIError(
#     138         "The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable"
#     139     )
#     140 if callable(api_key):
#     141     self.api_key = ""
#
# OpenAIError: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable

# %%
def ask_question(prompt):
    print(f"User asked: {prompt}")
    # my_client.chat.completions.create
    system_prompt_message={"role": "system", "content": "You are a helpful assistant. Answer as concisely as possible."}
    user_prompt_message={"role": "user", "content": prompt}
    llm_response = my_client.chat.completions.create(
        model="gpt-5-nano",
        messages=[system_prompt_message, user_prompt_message]   
    )
    print (llm_response)

    # prompt = ChatPromptTemplate.from_messages([
    #     ("system", "You are a helpful assistant."),
    #     ("human", "{question}")
    # ])
    # # print(prompt.invoke({"question": "What is AI?"}))
    # prompt | llm
    # llm = OpenAI(model="gpt-5-nano")

    return llm_response.choices[0].message.content  

    # parser = StrOutputParser()
    # result = parser.invoke(resp)
    # return result

# %%
import time
while True:
    # Ask user for a question
    user_prompt = input("Ask something: ")

    if (user_prompt.lower() != 'quit'):
        # Get and print the response
        response = ask_question(user_prompt)
        print("\nOpenAI says:", response)
        
        # add delay of 3 seconds
        time.sleep(3)
    else:
        print("Exiting...")
        break
