# %%
# %pip install python-dotenv
# %pip install openai

# %%
# !ls ../.env.local
# Out:
# ../.env.local

# %%
import os
from dotenv import load_dotenv

load_dotenv(override=True, dotenv_path="../.env.local")
my_api_key = os.getenv("OPENAI_API_KEY")
print(my_api_key)
my_api_key[:5], my_api_key[-10:]
# print(my_api_key)
# Out:
# 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
# ('sk-pr', 'sfIS94LLQA')

# %%
# %pip install openai

# %%
from openai import OpenAI
client = OpenAI(api_key=my_api_key)

# %%
prompt = "Tell me a story about Akbar Birbal"
try:
    response = client.chat.completions.create(
        model="gpt-5-nano", #"gpt-5-turbo", #"gpt-5", #"gpt-5-mini", #"gpt-5-nano"
        messages=[
            {"role": "system", "content": "You are a helpful assistant. Answer the user's questions concisely."},
            {"role": "user", "content": "Tell me a story about Akbar Birbal"}
            # {"role": "user", "content": f"Here is the context: \n\ {context} \n\. \n\n Now, answer the question: {prompt}")
        ],
        # temperature=0.7,
        # max_completion_tokens=256,
    )
    print (response)
    print (response.choices[0].message.content)
except Exception as e:
    print(f"Error occurred: {e}")
# Out:
# ChatCompletion(id='chatcmpl-CzRjLnfON1YLUd0p1jywwD08Q4H5c', choices=[Choice(finish_reason='length', index=0, logprobs=None, message=ChatCompletionMessage(content='', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1768760639, model='gpt-5-nano-2025-08-07', object='chat.completion', service_tier='default', system_fingerprint=None, usage=CompletionUsage(completion_tokens=256, prompt_tokens=33, total_tokens=289, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=256, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
