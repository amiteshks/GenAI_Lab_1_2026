# %%
import os
from dotenv import load_dotenv
from openai import OpenAI

load_dotenv(override=True, dotenv_path="../.env.local")
my_api_key = os.getenv("OPENAI_API_KEY")
my_api_key[:5], my_api_key[-10:]
client = OpenAI(api_key=my_api_key)

# %%
def get_response_from_model(prompt):
    response = client.chat.completions.create(
    model="gpt-5-nano",
    messages=[
        {"role": "system", "content": "You are a helpful assistant. Answer as a csv fields title, description, time_data_extracted"},
        {"role": "user", "content": prompt}
        # {"role": "user", "content": f"Here is the context: \n\ {context} \n\. \n\n Now, answer the question: {prompt}")
    ]
)
    # print (response)
    # print (response.choices[0].message.content)
    return response.choices[0].message.content

# %%
import time
while True:
    # Ask user for a question
    user_prompt = input("Ask something: ")

    if (user_prompt.lower() != 'quit'):
        # Get and print the response
        response = get_response_from_model(user_prompt)
        print("\nOpenAI says:", response)
        
        # add delay of 3 seconds
        time.sleep(3)
    else:
        print("Exiting the loop. Goodbye!")
        break
# Out:
# OpenAI says: title,description,time_data_extracted
# FIFA World Cup 2026 dates,"The 2026 FIFA World Cup is scheduled to be held in June and July 2026 across Canada, Mexico, and the United States. The exact opening match date and final date will be announced by FIFA; the tournament typically runs for about a month.","June–July 2026; hosts: Canada, Mexico, USA; opening match early June 2026; final mid-to-late July 2026 (exact dates TBA)."
# Exiting the loop. Goodbye!
